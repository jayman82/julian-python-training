# %% [markdown]
# # 👋 Hello, Julian!
# Welcome to Python with a trick shot twist!
# Let's start with printing some messages.

# %%
print("Let's go Julian! 🏀")
print("You're a Python champ!")

# %% [markdown]
# ## 🎯 Your Turn
# Try writing your own family cheer below!

# %%
print("Give me a J!")
print("Give me a U!")
print("What does that spell? JULIAN!")
