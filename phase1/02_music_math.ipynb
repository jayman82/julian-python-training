# %% [markdown]
# # 🎵 Playlist Calculator
# Let’s do math with music and your phone!

# %%
songs = int(input('How many songs do you listen to each day? '))
days = int(input('For how many days? '))
total = songs * days
print(f'That’s {total} songs in {days} days! 🎧')
