# %% [markdown]
# # 🏡 Decision Maker
# Help Julian pick what to do based on the weather.

# %%
weather = input('Is it sunny, rainy, or cloudy? ').lower()
if weather == 'sunny':
    print('Time for a backyard trick shot! 🏀')
elif weather == 'cloudy':
    print('Let’s build a Dude Perfect obstacle course inside! 🧱')
else:
    print('Movie time with family! 🎬')
