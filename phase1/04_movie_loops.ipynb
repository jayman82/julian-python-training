# %% [markdown]
# # 🎬 Julian’s Movie Picks
# Let’s loop through a movie watchlist!

# %%
movies = ['Space Jam', 'Minions', 'Sonic the Hedgehog']
for movie in movies:
    print(f'Julian wants to watch: {movie}')
