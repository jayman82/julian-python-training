# %% [markdown]
# # 👨‍👩‍👦 Praise Your Family with Functions
# Write a function to compliment them!

# %%
def praise(name):
    print(f'{name}, you’re awesome! 💯')

praise('Mom')
praise('Dad')

# %% [markdown]
# ## 🎯 Your Turn
# Add more names to praise!

# %%
# Try praising your siblings or a friend!
