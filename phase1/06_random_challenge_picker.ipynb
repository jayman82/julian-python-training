# %% [markdown]
# # 🎯 Challenge Picker
# Pick a random Dude Perfect challenge!

# %%
import random
challenges = ['Trick shot off the couch', 'Ping pong bounce challenge', 'Create your own basketball trick']
pick = random.choice(challenges)
print(f'Julian’s challenge is: {pick}')
